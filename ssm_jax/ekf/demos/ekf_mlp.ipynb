# %% [markdown]
# <a href="https://colab.research.google.com/github/petergchang/ssm-jax/blob/main/ssm_jax/ekf/demos/ekf_mlp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MLP training using extended Kalman filter
#
# We use the [ssm-jax](https://github.com/probml/ssm-jax/blob/main/ssm_jax/) library.

# %%
# Silence WARNING:root:The use of `check_types` is deprecated and does not have any effect.
# https://github.com/tensorflow/probability/issues/1523
import logging

logger = logging.getLogger()


class CheckTypesFilter(logging.Filter):
    def filter(self, record):
        return "check_types" not in record.getMessage()


logger.addFilter(CheckTypesFilter())

# %%
try:
    from ssm_jax.ekf.demos.ekf_mlp import *
except ModuleNotFoundError:
    # %pip install -qq git+https://github.com/probml/ssm-jax.git
    from ssm_jax.ekf.demos.ekf_mlp import *


dict_figures = main()
for k, v in dict_figures.items():
    fname = k + ".pdf"
    print(fname)
    fig = v
    fig.savefig(fname)

plt.show()
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# step 10.pdf
# step 20.pdf
# step 30.pdf
# step 200.pdf
